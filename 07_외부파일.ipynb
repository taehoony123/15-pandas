# %%
# CSV
# pandas.read_csv("파일경로(이름)")

import pandas as pd
import os

# 경로 폴더의 모든 파일 목록 확인하기
os.listdir("./datasets")
# Out:
# ['read_csv_sample.csv']

# %%
# 파일 경로를 찾고, 변수  file_path에 저장
file_path = './datasets/read_csv_sample.csv'

print(file_path)
# Out:
# ./datasets/read_csv_sample.csv

# %%
# 파일의 경로를 찾고, 변수 file_path에 저장(os모듈 활용)
file_path2 = os.path.join('datasets','read_csv_sample.csv')
print(file_path2)
# Out:
# datasets\read_csv_sample.csv

# %% [markdown]
# ## 파일 읽기

# %%
df1 = pd.read_csv(file_path)
print(df1)
print()
df2 = pd.read_csv(file_path, header=None)
print(df2)
print()
df3 = pd.read_csv(file_path, index_col=None)
print(df3)
print()
df4 = pd.read_csv(file_path, index_col='c0')
print(df4)
# Out:
#    c0  c1  c2  c3
# 0   0   1   4   7
# 1   1   2   5   8
# 2   2   3   6   9
#
#     0   1   2   3
# 0  c0  c1  c2  c3
# 1   0   1   4   7
# 2   1   2   5   8
# 3   2   3   6   9
#
#    c0  c1  c2  c3
# 0   0   1   4   7
# 1   1   2   5   8
# 2   2   3   6   9
#
#     c1  c2  c3
# c0
# 0    1   4   7
# 1    2   5   8
# 2    3   6   9
